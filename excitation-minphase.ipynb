# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import islr
import util
import sigpy as sp
import sigpy.mri.rf as rf

# %% [markdown]
# # Set parameters

# %%
n = 64  # Pulse length
tb = 8  # Time bandwidth
d1 = 0.01  # Passband ripple
d2 = 0.01  # Stopband ripple

# %% [markdown]
# # Design RF pulse using the original SLR

# %%
b1_slr = rf.dzrf(n=n, tb=tb, ptype='ex', ftype='min', d1=d1, d2=d2)

# %%
figs = util.plot_rf(b1_slr)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Design RF pulse using the improved SLR

# %%
b1_islr = islr.dzrf(n=n, tb=tb, ptype='ex-minphase', d1=d1, d2=d2, 
                    eps=1, sigma=1000, max_iter=30000)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='DesignPaulynomials', max=30000.0, style=ProgressStyle(des…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-9f1560d34db6> in <module>
#       1 b1_islr = islr.dzrf(n=n, tb=tb, ptype='ex-minphase', d1=d1, d2=d2,
# ----> 2                     eps=1, sigma=1000, max_iter=30000)
#
# ~/slr/islr.py in dzrf(n, tb, ptype, d1, d2, m, max_iter, sigma, eps, return_P)
#      64         return app.run()
#      65     else:
# ---> 66         a, b = app.run()
#      67         b1 = rf.ab2rf(a[::-1], b[::-1])
#      68         return b1
#
# ~/sigpy/sigpy/app.py in run(self)
#      83
#      84             self._pre_update()
# ---> 85             self.alg.update()
#      86             self._post_update()
#      87
#
# ~/sigpy/sigpy/alg.py in update(self)
#      61         Call the user-defined _update() function and increment iter.
#      62         """
# ---> 63         self._update()
#      64         self.iter += 1
#      65
#
# ~/sigpy/sigpy/alg.py in _update(self)
#     361             x_old = self.x.copy()
#     362             util.axpy(self.x, -self.tau, self.AH(self.u))
# --> 363             backend.copyto(self.x, self.proxg(self.tau, self.x))
#     364
#     365         # Update step-size if neccessary.
#
# ~/sigpy/sigpy/prox.py in __call__(self, alpha, input)
#      47         try:
#      48             self._check_shape(input)
# ---> 49             output = self._prox(alpha, input)
#      50             self._check_shape(output)
#      51         except Exception as e:
#
# ~/slr/prox.py in _prox(self, alpha, input)
#      16         output[0, n + 1] += alpha * self.eps
#      17
# ---> 18         return sp.psd_proj(output)
#
# ~/sigpy/sigpy/thresh.py in psd_proj(input)
#     144     """
#     145     xp = backend.get_array_module(input)
# --> 146     w, v = xp.linalg.eigh(input)
#     147     w[w < 0] = 0
#     148     return (v * w) @ v.conjugate().T
#
# <__array_function__ internals> in eigh(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in eigh(a, UPLO)
#    1469
#    1470     signature = 'D->dD' if isComplexType(t) else 'd->dd'
# -> 1471     w, vt = gufunc(a, signature=signature, extobj=extobj)
#    1472     w = w.astype(_realType(result_t), copy=False)
#    1473     vt = vt.astype(result_t, copy=False)
#
# KeyboardInterrupt:

# %%
figs = util.plot_rf(b1_islr)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
