# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import islr
import util
import sigpy as sp
import sigpy.mri.rf as rf

# %% [markdown]
# # Set parameters

# %%
n = 64  # Pulse length
tb = 8  # Time bandwidth
d1 = 0.01  # Passband ripple
d2 = 0.01  # Stopband ripple

# %% [markdown]
# # Design RF pulse using the original SLR

# %%
b1_slr = rf.dzrf(n=n, tb=tb, ptype='ex', ftype='min', d1=d1, d2=d2)

# %%
figs = util.plot_rf(b1_slr, magphase=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Design RF pulse using the improved SLR

# %%
b1_islr = islr.dzrf(n=n, tb=tb, ptype='ex-minphase', d1=d1, d2=d2)

# %%
figs = util.plot_rf(b1_islr, magphase=True)# Design RF pulse using the improved SLR
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
