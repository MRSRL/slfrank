# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import islr
import numpy as np
import util
import sigpy as sp
import sigpy.mri.rf as rf# Set parameters

# %% [markdown]
# # Set parameters

# %%
n = 64  # Pulse length
tb = 8  # Time bandwidth
d1 = 0.01  # Passband ripple
d2 = 0.01  # Stopband ripple

# %%
rf.dzrf?

# %% [markdown]
# # Design RF pulse using the original SLR

# %%
b1_slr = rf.dzrf(n=n, tb=tb, ptype='se', ftype='pm', d1=d1, d2=d2)

# %%
figs = util.plot_rf(b1_slr, spin_echo=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Design RF pulse using the improved SLR

# %%
b1_islr = islr.dzrf(n=n, tb=tb, ptype='inv', d1=d1, d2=d2, max_iter=20000)

# %%
figs = util.plot_rf(b1_islr)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
